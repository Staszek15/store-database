# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
data = {
        'first_name': ['Tomasz', 'Karolina', 'Mateusz', 'Wiktoria', 'Julia'],
       'last_name': ['Stroiński', 'Wypych', 'Stasiak', 'Fimińska', 'Grzegorzewska'],
        'salary': [5000, 3500, 3500, 3500, 3500],
        'birth_date': ['1995-01-01', '2001-09-03', '2001-10-15', '2001-02-02', '2001-09-03'],
        'start': ['2018-05-04', '2020-01-03', '2020-02-18', '2019-02-04', '2020-04-08'],
        'phone': ['923128647', '756837957', '567938928', '566552356', '666555827'],
        'address_id': [5,3,1,2,4],
        'email': ['t.stroinski@gamefinity.com', 'k.wypych@gamefinity.com', 'm.stasiak@gamefinity.com', 
                  'w.fiminska@gamefinity.com', 'j.grzegorzewska@gamefinity.com']
       }

staff = pd.DataFrame(data)
staff
# Out:
#   first_name      last_name  salary  birth_date       start      phone  \
# 0     Tomasz      Stroiński    5000  1995-01-01  2018-05-04  923128647
# 1   Karolina         Wypych    3500  2001-09-03  2020-01-03  756837957
# 2    Mateusz        Stasiak    3500  2001-10-15  2020-02-18  567938928
# 3   Wiktoria       Fimińska    3500  2001-02-02  2019-02-04  566552356
# 4      Julia  Grzegorzewska    3500  2001-09-03  2020-04-08  666555827
#
#    address_id                           email
# 0           5      t.stroinski@gamefinity.com
# 1           3         k.wypych@gamefinity.com
# 2           1        m.stasiak@gamefinity.com
# 3           2       w.fiminska@gamefinity.com
# 4           4  j.grzegorzewska@gamefinity.com

# %%
staff.to_csv('staff.csv')
